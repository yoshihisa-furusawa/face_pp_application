# %%
import numpy as np
import json
import matplotlib.pylab as plt
from PIL import Image

# %%
with open("./output.json", "r") as f:
    data = json.load(f)

# %%
data[0]
# Out:
# {'time_used': 258,
#  'faces': [{'landmark': {'mouth_upper_lip_left_contour2': {'y': 145, 'x': 76},
#     'mouth_upper_lip_top': {'y': 143, 'x': 85},
#     'mouth_upper_lip_left_contour1': {'y': 142, 'x': 82},
#     'left_eye_upper_left_quarter': {'y': 94, 'x': 67},
#     'left_eyebrow_lower_middle': {'y': 82, 'x': 69},
#     'mouth_upper_lip_left_contour3': {'y': 148, 'x': 79},
#     'right_eye_top': {'y': 91, 'x': 100},
#     'left_eye_bottom': {'y': 97, 'x': 71},
#     'right_eyebrow_lower_left_quarter': {'y': 81, 'x': 96},
#     'right_eye_pupil': {'y': 93, 'x': 100},
#     'mouth_lower_lip_right_contour1': {'y': 149, 'x': 93},
#     'mouth_lower_lip_right_contour3': {'y': 154, 'x': 91},
#     'mouth_lower_lip_right_contour2': {'y': 152, 'x': 96},
#     'contour_chin': {'y': 172, 'x': 87},
#     'contour_left9': {'y': 170, 'x': 76},
#     'left_eye_lower_right_quarter': {'y': 97, 'x': 75},
#     'mouth_lower_lip_top': {'y': 149, 'x': 86},
# ...

# %%
number_img = 1
img = np.array(Image.open(data[number_img]["image_path"]))/255
h, w, c = img.shape

# %%
plt.imshow(img)
for _, cood in data[number_img]["faces"][0]["landmark"].items():
    plt.scatter(cood["x"], cood["y"], c="b")

# %%
face_land
# Out:
# ('mouth_upper_lip_bottom', {'y': 148, 'x': 86})
